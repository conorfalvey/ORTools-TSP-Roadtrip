# %% [markdown]
# # Traveling Salesman Problem Implementation in Google ORTools, Google Maps Distance Matrix API, and Google Earth/Maps KML Exportation
# ## Conor Falvey, 2022

# %%
# Imports
import os
import ortools
import pandas as pd
import numpy as np
import urllib.parse
import requests
from pathlib import Path
from ortools.constraint_solver import pywrapcp
from ortools.constraint_solver import routing_enums_pb2

# %%
# Configs
# Jupyter/Pandas display params
from IPython.core.display import display, HTML
display(HTML("<style>div.output_area pre {white-space: pre;}</style>"))
pd.options.display.max_rows = 4000
pd.options.display.max_columns = 4000

# Pathing, Requests, Map Stuff, etc.
CSV_FOLDER = Path(os.getcwd() + "/data")
BASE_URL = "https://maps.googleapis.com/maps/api/distancematrix"
OUTPUT = "json"
API_KEY = ""
START = "San Francisco"
DEST_LIMIT = 25
# Out:
# <style>div.output_area pre {white-space: pre;}</style>

# %%
# Import all csv files from data
# This is now not very needed as all 3 files have
# been concatenated together.
def import_places(path: Path):
    places = []
    for path in path.glob('*.csv'):
        places.append(pd.read_csv(path))
    df = pd.concat(places)[["X", "Y", "Name"]]
    return df

# %%
# You can either move around the order of the CSV
# file to determine the start and skip this, but
# I started added formatting here so I kept it.
def define_start(df: pd.DataFrame):
    # Get row index of starting name
    start_row = df[df["Name"] == START]
    # Drop row, add to index -1, increment index,
    # sort, and reset indices as a hacky way to
    # force an element to the top
    df = df.drop(start_row.index)
    df.loc[-1] = start_row.iloc[0]
    df.index = df.index + 1
    df.sort_index(inplace=True)
    df = df.reset_index(drop=True)
    # Casting for combining coords
    df["X"] = df["X"].astype(str)
    df["Y"] = df["Y"].astype(str)
    df["Coords"] = df[['Y', 'X']].agg(','.join, axis=1)
    return df

# %%
# The Google Maps Distance Matrix API takes nxm origins
# and destinations. To simplify things, we iterate over
# singular origins and feed in all possible destinations.
# The endpoint has a 25 destination limit per request, so
# we paginate and join them before adding them into the 
# distance matrix. If no route is found, we set the distance
# to 999999999 in the next method so we can easily find them 
# later and print out information about its coordinates to 
# manually double check in Google maps and update the coordinates.
def req_distance_matrix(df: pd.DataFrame):
    length = df.shape[0]
    matrix = np.empty((length, length), dtype=int)
    for i, r in df.iterrows():
        print(f"Calculating Routes from {r['Name']}")
        origin = r["Coords"]
        raw_dests = df["Coords"]
        distances = []
        for chunk in [raw_dests[i:i + DEST_LIMIT] for i in range(0, len(raw_dests), DEST_LIMIT)]:
            dests = "|".join(chunk)
            dists = get_maps_distance(origin, dests)
            if 999999999 in dists:
                print(f"{i}    {dists.index(999999999)}    {chunk.iloc[0]}    {dests}")
            distances.extend(dists)
        matrix[i] = distances
    return matrix

# %%
# Format the URL into the endpoints expectations and
# check it completed ok. If no route is found, the 
# status of that element will be 'NOT_FOUND', so we 
# check for an OK code.
def get_maps_distance(origin: str, dest: str):
    url = format_url(origin, dest)
    req = requests.get(url)
    if not req.ok:
        raise ValueError
    dists = []
    for x in req.json()["rows"][0]["elements"]:
        if x["status"] == "OK":
            dists.append(x["distance"]["value"])
        else:
            dists.append(999999999)
    return dists

# %%
# URL encode the URL and format together
def format_url(origin: str, dest: str):
    format_origin = urllib.parse.quote_plus(origin)
    format_dest = urllib.parse.quote_plus(dest)
    return f"{BASE_URL}/{OUTPUT}?origins={format_origin}&destinations={format_dest}&key={API_KEY}"

# %%
# Main method to import DF, format it,
# and compute the distance matrix. It
# takes 1183 requents to compute everything 
# with destination limits on the endpoint
def main():
    df = import_places(CSV_FOLDER)
    df = define_start(df)
    matrix = req_distance_matrix(df)
    return df, matrix

# %%
d, m = main()
# Out:
# Calculating Routes from San Francisco
# Calculating Routes from New York
# Calculating Routes from Los Angeles
# Calculating Routes from Chicago
# Calculating Routes from Houston
# Calculating Routes from Philadelphia
# Calculating Routes from San Antonio
# Calculating Routes from San Diego
# Calculating Routes from Dallas
# Calculating Routes from San Jose
# Calculating Routes from Jacksonville
# Calculating Routes from Fort Worth
# Calculating Routes from Charlotte
# Calculating Routes from Seattle
# Calculating Routes from Washington
# Calculating Routes from El Paso
# Calculating Routes from Portland
# Calculating Routes from Las Vegas
# Calculating Routes from Detroit
# Calculating Routes from Memphis
# Calculating Routes from Louisville
# Calculating Routes from Baltimore
# Calculating Routes from Milwaukee
# Calculating Routes from Albuquerque
# Calculating Routes from Tucson
# Calculating Routes from Fresno
# Calculating Routes from Kansas City
# Calculating Routes from Mesa
# Calculating Routes from Omaha
# Calculating Routes from Colorado Springs
# Calculating Routes from Long Beach
# Calculating Routes from Virginia Beach
# Calculating Routes from Miami
# Calculating Routes from Oakland
# Calculating Routes from Minneapolis
# Calculating Routes from Tulsa
# Calculating Routes from Bakersfield
# Calculating Routes from Wichita
# Calculating Routes from Arlington
# Calculating Routes from Aurora
# Calculating Routes from Tampa
# Calculating Routes from New Orleans
# Calculating Routes from Cleveland
# Calculating Routes from Anaheim
# Calculating Routes from Lexington
# Calculating Routes from Stockton
# Calculating Routes from Corpus Christi
# Calculating Routes from Henderson
# Calculating Routes from Riverside
# Calculating Routes from Newark
# Calculating Routes from Santa Ana
# Calculating Routes from Cincinnati
# Calculating Routes from Irvine
# Calculating Routes from Orlando
# Calculating Routes from Pittsburgh
# Calculating Routes from St. Louis
# Calculating Routes from Greensboro
# Calculating Routes from Jersey City
# Calculating Routes from Plano
# Calculating Routes from Durham
# Calculating Routes from Buffalo
# Calculating Routes from Chandler
# Calculating Routes from Chula Vista
# Calculating Routes from Toledo
# Calculating Routes from Gilbert
# Calculating Routes from Reno
# Calculating Routes from Fort Wayne
# Calculating Routes from North Las Vegas
# Calculating Routes from St. Petersburg
# Calculating Routes from Lubbock
# Calculating Routes from Irving
# Calculating Routes from Laredo
# Calculating Routes from Montgomery
# Calculating Routes from Phoenix
# Calculating Routes from Little Rock
# Calculating Routes from Sacramento
# Calculating Routes from Denver
# Calculating Routes from Hartford
# Calculating Routes from Dover
# Calculating Routes from Tallahassee
# Calculating Routes from Atlanta
# Calculating Routes from Boise
# Calculating Routes from Springfield
# Calculating Routes from Indianapolis
# Calculating Routes from Des Moines
# Calculating Routes from Topeka
# Calculating Routes from Frankfort
# Calculating Routes from Baton Rouge
# Calculating Routes from Augusta
# Calculating Routes from Annapolis
# Calculating Routes from Boston
# Calculating Routes from Lansing
# Calculating Routes from Saint Paul
# Calculating Routes from Jackson
# Calculating Routes from Jefferson City
# Calculating Routes from Helena
# Calculating Routes from Lincoln
# Calculating Routes from Carson City
# Calculating Routes from Concord
# Calculating Routes from Trenton
# Calculating Routes from Santa Fe
# Calculating Routes from Albany
# Calculating Routes from Raleigh
# Calculating Routes from Bismarck
# Calculating Routes from Columbus
# Calculating Routes from Oklahoma City
# Calculating Routes from Salem
# Calculating Routes from Harrisburg
# Calculating Routes from Providence
# Calculating Routes from Columbia
# Calculating Routes from Pierre
# Calculating Routes from Nashville
# Calculating Routes from Austin
# Calculating Routes from Salt Lake City
# Calculating Routes from Montpelier
# Calculating Routes from Richmond
# Calculating Routes from Olympia
# Calculating Routes from Charleston
# Calculating Routes from Madison
# Calculating Routes from Cheyenne
# Calculating Routes from Grand Canyon National Park
# Calculating Routes from Petrified Forest National Park
# Calculating Routes from Saguaro National Park
# Calculating Routes from Guadalupe Mountains National Park
# Calculating Routes from Carlsbad Caverns National Park
# Calculating Routes from White Sands National Park
# Calculating Routes from Big Bend National Park
# Calculating Routes from Hot Springs National Park
# Calculating Routes from Mammoth Cave National Park
# Calculating Routes from Gateway Arch National Park
# Calculating Routes from Indiana Dunes National Park
# Calculating Routes from Great Smoky Mountains National Park
# Calculating Routes from Everglades National Park
# Calculating Routes from Biscayne National Park
# Calculating Routes from Congaree National Park
# Calculating Routes from Shenandoah National Park
# Calculating Routes from New River Gorge National Park and Preserve
# Calculating Routes from Acadia National Park
# Calculating Routes from Cuyahoga Valley National Park
# Calculating Routes from Isle Royale National Park
# Calculating Routes from Voyageurs National Park
# Calculating Routes from Theodore Roosevelt National Park
# Calculating Routes from Badlands National Park
# Calculating Routes from Wind Cave National Park
# Calculating Routes from Rocky Mountain National Park
# Calculating Routes from Great Sand Dunes National Park and Preserve
# Calculating Routes from Black Canyon of the Gunnison National Park
# Calculating Routes from Mesa Verde National Park
# Calculating Routes from Canyonlands National Park
# Calculating Routes from Arches National Park
# Calculating Routes from Capitol Reef National Park
# Calculating Routes from Bryce Canyon National Park
# Calculating Routes from Zion National Park
# Calculating Routes from Great Basin National Park
# Calculating Routes from Grand Teton National Park
# Calculating Routes from Yellowstone National Park
# Calculating Routes from Glacier National Park
# Calculating Routes from Mount Rainier National Park
# Calculating Routes from Olympic National Park
# Calculating Routes from Crater Lake National Park
# Calculating Routes from Redwood National and State Parks
# Calculating Routes from Lassen Volcanic National Park
# Calculating Routes from Yosemite National Park
# Calculating Routes from Kings Canyon National Park
# Calculating Routes from Sequoia National Park
# Calculating Routes from Pinnacles National Park
# Calculating Routes from Channel Islands National Park
# Calculating Routes from Joshua Tree National Park
# Calculating Routes from Death Valley National Park

# %%
# Setup data and router for TSP in ORTools
data = {}
data['distance_matrix'] = m
data['num_vehicles'] = 1
data['depot'] = 0

manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']), data['num_vehicles'], data['depot'])
routing = pywrapcp.RoutingModel(manager)

# %%
# Returns distance between two locations given the 
# distance matrix above
def distance_callback(from_index, to_index):
    from_node = manager.IndexToNode(from_index)
    to_node = manager.IndexToNode(to_index)
    return data['distance_matrix'][from_node][to_node]

# %%
# Standard Solution Printer from documentation with added
# list tracking so we can index into the dataframe from 
# earlier and print out an ordered list of locations on the route
def print_solution(manager, routing, solution):
    """Prints solution on console."""
    print('Objective: {} meters'.format(solution.ObjectiveValue()))
    index = routing.Start(0)
    plan_output = 'Route for vehicle 0:\n'
    route_distance = 0
    idx_list = []
    while not routing.IsEnd(index):
        idx = manager.IndexToNode(index)
        idx_list.append(idx)
        plan_output += ' {} ->'.format(idx)
        previous_index = index
        index = solution.Value(routing.NextVar(index))
        route_distance += routing.GetArcCostForVehicle(previous_index, index, 0)
    plan_output += ' {}\n'.format(manager.IndexToNode(index))
    idx_list.append(manager.IndexToNode(index))
    plan_output += 'Route distance: {} meters\n'.format(route_distance)
    print(plan_output)
    return idx_list

# %%
# General setup of callbacks and routing algorithms
transit_callback_index = routing.RegisterTransitCallback(distance_callback)
routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)
search_parameters = pywrapcp.DefaultRoutingSearchParameters()
search_parameters.first_solution_strategy = routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC

# Solve away!
solution = routing.SolveWithParameters(search_parameters)
if solution:
    l = print_solution(manager, routing, solution)
# Out:
# Objective: 36902198 meters
# Route for vehicle 0:
#  0 -> 45 -> 75 -> 161 -> 160 -> 159 -> 106 -> 16 -> 157 -> 116 -> 158 -> 13 -> 156 -> 95 -> 155 -> 154 -> 81 -> 113 -> 150 -> 149 -> 148 -> 147 -> 146 -> 145 -> 29 -> 39 -> 76 -> 144 -> 119 -> 143 -> 142 -> 110 -> 141 -> 103 -> 140 -> 139 -> 92 -> 34 -> 84 -> 28 -> 96 -> 85 -> 26 -> 94 -> 55 -> 129 -> 82 -> 118 -> 22 -> 3 -> 130 -> 83 -> 66 -> 91 -> 18 -> 63 -> 138 -> 42 -> 60 -> 54 -> 107 -> 101 -> 114 -> 137 -> 88 -> 98 -> 90 -> 108 -> 77 -> 1 -> 57 -> 99 -> 5 -> 78 -> 89 -> 21 -> 14 -> 135 -> 115 -> 31 -> 102 -> 59 -> 56 -> 12 -> 109 -> 134 -> 10 -> 53 -> 32 -> 133 -> 132 -> 68 -> 40 -> 79 -> 72 -> 80 -> 131 -> 136 -> 117 -> 104 -> 51 -> 44 -> 86 -> 20 -> 128 -> 111 -> 19 -> 74 -> 127 -> 93 -> 41 -> 87 -> 4 -> 46 -> 71 -> 6 -> 112 -> 11 -> 38 -> 70 -> 8 -> 58 -> 35 -> 37 -> 105 -> 69 -> 126 -> 124 -> 123 -> 15 -> 125 -> 100 -> 23 -> 121 -> 120 -> 73 -> 27 -> 64 -> 61 -> 122 -> 24 -> 62 -> 7 -> 52 -> 50 -> 43 -> 30 -> 166 -> 2 -> 48 -> 167 -> 168 -> 47 -> 17 -> 67 -> 152 -> 151 -> 153 -> 65 -> 97 -> 162 -> 25 -> 164 -> 36 -> 163 -> 165 -> 9 -> 49 -> 33 -> 0

# %%
# Print out ordered list of locations
# that we can implement the route for in 
# Google Maps and Google Earth to plot
for idx, el in enumerate(l):
    print(f"{idx}:\t{d.iloc[el]['Name']}")
# Out:
# 0:	San Francisco
# 1:	Stockton
# 2:	Sacramento
# 3:	Lassen Volcanic National Park
# 4:	Redwood National and State Parks
# 5:	Crater Lake National Park
# 6:	Salem
# 7:	Portland
# 8:	Mount Rainier National Park
# 9:	Olympia
# 10:	Olympic National Park
# 11:	Seattle
# 12:	Glacier National Park
# 13:	Helena
# 14:	Yellowstone National Park
# 15:	Grand Teton National Park
# 16:	Boise
# 17:	Salt Lake City
# 18:	Capitol Reef National Park
# 19:	Arches National Park
# 20:	Canyonlands National Park
# 21:	Mesa Verde National Park
# 22:	Black Canyon of the Gunnison National Park
# 23:	Great Sand Dunes National Park and Preserve
# 24:	Colorado Springs
# 25:	Aurora
# 26:	Denver
# 27:	Rocky Mountain National Park
# 28:	Cheyenne
# 29:	Wind Cave National Park
# 30:	Badlands National Park
# 31:	Pierre
# 32:	Theodore Roosevelt National Park
# 33:	Bismarck
# 34:	Voyageurs National Park
# 35:	Isle Royale National Park
# 36:	Saint Paul
# 37:	Minneapolis
# 38:	Des Moines
# 39:	Omaha
# 40:	Lincoln
# 41:	Topeka
# 42:	Kansas City
# 43:	Jefferson City
# 44:	St. Louis
# 45:	Gateway Arch National Park
# 46:	Springfield
# 47:	Madison
# 48:	Milwaukee
# 49:	Chicago
# 50:	Indiana Dunes National Park
# 51:	Indianapolis
# 52:	Fort Wayne
# 53:	Lansing
# 54:	Detroit
# 55:	Toledo
# 56:	Cuyahoga Valley National Park
# 57:	Cleveland
# 58:	Buffalo
# 59:	Pittsburgh
# 60:	Harrisburg
# 61:	Albany
# 62:	Montpelier
# 63:	Acadia National Park
# 64:	Augusta
# 65:	Concord
# 66:	Boston
# 67:	Providence
# 68:	Hartford
# 69:	New York
# 70:	Jersey City
# 71:	Trenton
# 72:	Philadelphia
# 73:	Dover
# 74:	Annapolis
# 75:	Baltimore
# 76:	Washington
# 77:	Shenandoah National Park
# 78:	Richmond
# 79:	Virginia Beach
# 80:	Raleigh
# 81:	Durham
# 82:	Greensboro
# 83:	Charlotte
# 84:	Columbia
# 85:	Congaree National Park
# 86:	Jacksonville
# 87:	Orlando
# 88:	Miami
# 89:	Biscayne National Park
# 90:	Everglades National Park
# 91:	St. Petersburg
# 92:	Tampa
# 93:	Tallahassee
# 94:	Montgomery
# 95:	Atlanta
# 96:	Great Smoky Mountains National Park
# 97:	New River Gorge National Park and Preserve
# 98:	Charleston
# 99:	Columbus
# 100:	Cincinnati
# 101:	Lexington
# 102:	Frankfort
# 103:	Louisville
# 104:	Mammoth Cave National Park
# 105:	Nashville
# 106:	Memphis
# 107:	Little Rock
# 108:	Hot Springs National Park
# 109:	Jackson
# 110:	New Orleans
# 111:	Baton Rouge
# 112:	Houston
# 113:	Corpus Christi
# 114:	Laredo
# 115:	San Antonio
# 116:	Austin
# 117:	Fort Worth
# 118:	Arlington
# 119:	Irving
# 120:	Dallas
# 121:	Plano
# 122:	Tulsa
# 123:	Wichita
# 124:	Oklahoma City
# 125:	Lubbock
# 126:	Big Bend National Park
# 127:	Carlsbad Caverns National Park
# 128:	Guadalupe Mountains National Park
# 129:	El Paso
# 130:	White Sands National Park
# 131:	Santa Fe
# 132:	Albuquerque
# 133:	Petrified Forest National Park
# 134:	Grand Canyon National Park
# 135:	Phoenix
# 136:	Mesa
# 137:	Gilbert
# 138:	Chandler
# 139:	Saguaro National Park
# 140:	Tucson
# 141:	Chula Vista
# 142:	San Diego
# 143:	Irvine
# 144:	Santa Ana
# 145:	Anaheim
# 146:	Long Beach
# 147:	Channel Islands National Park
# 148:	Los Angeles
# 149:	Riverside
# 150:	Joshua Tree National Park
# 151:	Death Valley National Park
# 152:	Henderson
# 153:	Las Vegas
# 154:	North Las Vegas
# 155:	Zion National Park
# 156:	Bryce Canyon National Park
# 157:	Great Basin National Park
# 158:	Reno
# 159:	Carson City
# 160:	Yosemite National Park
# 161:	Fresno
# 162:	Sequoia National Park
# 163:	Bakersfield
# 164:	Kings Canyon National Park
# 165:	Pinnacles National Park
# 166:	San Jose
# 167:	Newark
# 168:	Oakland
# 169:	San Francisco
